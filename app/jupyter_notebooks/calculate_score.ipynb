# %%
import pandas as pd
import sqlite3

# %%
conn1 =  sqlite3.connect("../database/predictions.sqlite")

# %%
predictions = pd.read_sql_query("SELECT * FROM EM328", conn1) ##

# %%
conn2 =  sqlite3.connect("../database/results.sqlite")

# %%
results = pd.read_sql_query("SELECT * FROM results", conn2)

# %%
result = results['Result']

# %%
predict = predictions['Prediction']

# %%
for i in range(result.size):
    if result[i] == 'NR':
        predictions['Points'][i] = 5
    elif result[i].strip().lower() == predict[i].strip().lower():
        predictions['Points'][i] = 10
    else:
        predictions['Points'][i] = 0

# %%
predictions.to_sql('EM328', conn1, if_exists= 'replace', index = False)  ##

# %%
conn1.close()

# %%
conn2.close()

# %%
conn3 = sqlite3.connect("../database/score.sqlite")

# %%
score = pd.read_sql_query("SELECT * FROM scores", conn3)

# %%
score['EM328'] = predictions["Points"].sum() ##

# %%
score.to_sql('scores', conn3, if_exists= 'replace', index = False)

# %%
conn3.close()

# %%
predictions
# Out:
#               Match/Team/Player     Prediction Points
# 0         Pakistan vs Sri Lanka       Pakistan      5
# 1         England vs Bangladesh        England     10
# 2     Afganistan vs New Zealand    New Zealand     10
# 3            Australia vs India          India     10
# 4   South Africa vs West Indies   South Africa      5
# 5       Bangladesh vs Sri Lanka     Bangladesh      5
# 6         Pakistan vs Australia      Australia     10
# 7          India vs New Zealand          India      5
# 8        England vs West Indies    West Indies      0
# 9        Australia vs Sri Lanka      Australia     10
# 10   Afganistan vs South Africa   South Africa     10
# 11            India vs Pakistan          India     10
# 12    Bangladesh vs West Indies    West Indies      0
# 13        England vs Afganistan        England     10
# 14  New Zealand vs South Africa   South Africa      0
# 15      Australia vs Bangladesh      Australia     10
# 16         England vs Sri Lanka        England      0
# 17          India vs Afganistan          India     10
# 18   New Zealand vs West Indies    New Zealand     10
# 19     Pakistan vs South Africa       Pakistan     10
# 20     Afganistan vs Bangladesh     Afganistan      0
# 21         England vs Australia      Australia     10
# 22      Pakistan vs New Zealand    New Zealand      0
# 23         India vs West Indies          India     10
# 24    Sri Lanka vs South Africa   South Africa   None
# 25       Pakistan vs Afganistan       Pakistan   None
# 26     Australia vs New Zealand      Australia   None
# 27             England vs India          India   None
# 28     Sri Lanka vs West Indies    West Indies   None
# 29          Bangladesh vs India          India   None
# 30       England vs New Zealand        England   None
# 31    Afganistan vs West Indies    West Indies   None
# 32       Pakistan vs Bangladesh       Pakistan   None
# 33           India vs Sri Lanka          India   None
# 34    Australia vs South Africa      Australia   None
# 35                 Semi Final-I          India   None
# 36                Semi Final-II      Australia   None
# 37                        Final          India   None
# 38            Semi-Finalist - I          India   None
# 39           Semi-Finalist - II      Australia   None
# 40          Semi-Finalist - III    West Indies   None
# 41           Semi-Finalist - IV        England   None
# 42              Highest Wickets     Matt Henry   None
# 43                 Highest Runs   David Warner   None
# 44            Man Of The Series  Hardik Pandya   None
# 45             Man Of The Match       KL Rahul   None

# %%
predictions["Points"].sum()
# Out:
# 160
