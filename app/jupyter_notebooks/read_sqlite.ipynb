# %%
import pandas as pd
import sqlite3

# %%
conn =  sqlite3.connect("../database/predictions.sqlite")

# %%
df = pd.read_sql_query("SELECT * FROM EM328", conn)

# %%
df
# Out:
#               Match/Team/Player     Prediction Points
# 0         Pakistan vs Sri Lanka       Pakistan   None
# 1         England vs Bangladesh        England   None
# 2     Afganistan vs New Zealand    New Zealand   None
# 3            Australia vs India          India   None
# 4   South Africa vs West Indies   South Africa   None
# 5       Bangladesh vs Sri Lanka     Bangladesh   None
# 6         Pakistan vs Australia      Australia   None
# 7          India vs New Zealand          India   None
# 8        England vs West Indies    West Indies   None
# 9        Australia vs Sri Lanka      Australia   None
# 10   Afganistan vs South Africa   South Africa   None
# 11            India vs Pakistan          India   None
# 12    Bangladesh vs West Indies    West Indies   None
# 13        England vs Afganistan        England   None
# 14  New Zealand vs South Africa   South Africa   None
# 15      Australia vs Bangladesh      Australia   None
# ...

# %%
conn.close()
