# %%
import pandas as pd
import sqlite3

# %%
conn =  sqlite3.connect("./data_base/predictions.sqlite")

# %%
df = pd.read_sql_query("SELECT * FROM predictions", conn)

# %%
df
# Out:
#                    Date                        Match     Chaitanya  \
# 0   2019-06-07 00:00:00        Pakistan vs Sri Lanka      Pakistan
# 1   2019-06-08 00:00:00        England vs Bangladesh       England
# 2   2019-06-08 00:00:00    Afganistan vs New Zealand   New Zealand
# 3   2019-06-09 00:00:00           Australia vs India         India
# 4   2019-06-10 00:00:00  South Africa vs West Indies   West Indies
# 5   2019-06-11 00:00:00      Bangladesh vs Sri Lanka    Bangladesh
# 6   2019-06-12 00:00:00        Pakistan vs Australia     Australia
# 7   2019-06-13 00:00:00         India vs New Zealand         India
# 8   2019-06-14 00:00:00       England vs West Indies       England
# 9   2019-06-15 00:00:00       Australia vs Sri Lanka     Australia
# 10  2019-06-15 00:00:00   Afganistan vs South Africa    Afganistan
# 11  2019-06-16 00:00:00            India vs Pakistan         India
# 12  2019-06-17 00:00:00    Bangladesh vs West Indies   West Indies
# ...
